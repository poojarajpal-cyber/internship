# %%
# importing libraries
import pandas as pd

# %%
# loading the dataset

# %%
df=pd .read_excel(r'D:\customer_retention_dataset.xlsx',sheet_name='datasheet')
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
# checking the shape 
df.shape
# Out:
# (269, 71)

# %%
# checking for nulls
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
# checking for other information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
# as we can see there are no nulls
# so we can proceed further

# %%
# to check for datatypes
df.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
# tocheck for description
df.describe()
# Out:
#        4 What is the Pin Code of where you shop online from?
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# max                                        560037.000000

# %%
# data visualizatiom

# %%
# making dataframe for nominal categorica

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
ax=sns.countplot(x="1Gender of respondent",data=df)
print(df["1Gender of respondent"].value_counts())
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %%
# we observe that number of females shop more than males

# %%
ax=sns.countplot(x="2 How old are you? ",data=df)
print(df["2 How old are you? "].value_counts())
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64

# %%
# in above visualization we observe that age group of 31 to 40 do more online shopping

# %%
ax=sns.countplot(x="3 Which city do you shop online from?",data=df)
print(df["3 Which city do you shop online from?"].value_counts())
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %%
# here we observe that more people love to buy from Delhi

# %%
ax=sns.countplot(x="5 Since How Long You are Shopping Online ?",data=df)
print(df["5 Since How Long You are Shopping Online ?"].value_counts())
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %%
# it seems that people are shopping online for more than 4 years

# %%
ax=sns.countplot(x="6 How many times you have made an online purchase in the past 1 year?",data=df)
print(df["6 How many times you have made an online purchase in the past 1 year?"].value_counts())
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64

# %%
# I observe that more people shopped online for not more than 42 times

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
ax=sns.countplot(x="7 How do you access the internet while shopping on-line?",data=df)
print(df["7 How do you access the internet while shopping on-line?"].value_counts())
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %%
# people liked to shop via mobile internet

# %%
ax=sns.countplot(x="8 Which device do you use to access the online shopping?",data=df)
print(df["8 Which device do you use to access the online shopping?"].value_counts())
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %%
# most of the people use smartphone to shop from online stores

# %%
ax=sns.countplot(x="9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ",data=df)
print(df["9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        "].value_counts())
# Out:
# Others        134
# 5.5 inches     99
# 4.7 inches     29
# 5 inches        7
# Name: 9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        , dtype: int64

# %%
#it is observed that very less people uses the device of 5 inches and more peopleuses the mobile phone of more than5.5 inches

# %%
ax=sns.countplot(x="10 What is the operating system (OS) of your device?\t\t\t\t                                          ",data=df)
print(df["10 What is the operating system (OS) of your device?\t\t\t\t                                          "].value_counts())
# Out:
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# Name: 10 What is the operating system (OS) of your device?\t\t\t\t                                          , dtype: int64

# %%
# it is observed that most of the people have windows opearting system and less people uses ios/mac phone

# %%
ax=sns.countplot(x=" 11 What browser do you run on your device to access the website?\t\t\t",data=df)
print(df[" 11 What browser do you run on your device to access the website?\t\t\t"].value_counts())
# Out:
# Google chrome      216
# Safari              40
# Opera                8
# Mozilla Firefox      5
# Name: 11 What browser do you run on your device to access the website?\t\t\t                                                          , dtype: int64

# %%
# most people uses google chrome  and very less use mozilla firefox

# %%
ax=sns.countplot(x="12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ",data=df)
print(df["12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   "].value_counts())
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: 12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   , dtype: int64

# %%
# most of the people uses search engine to arrive at their favourite online store for the first time

# %%
ax=sns.countplot(x="13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ",data=df)
print(df["13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   "].value_counts())
# Out:
# Search Engine      87
# Via application    86
# Direct URL         70
# E-mail             18
# Social Media        8
# Name: 13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   , dtype: int64

# %%
# most of the people uses search engine or through application or through url and very less people visit through e mail and social media

# %%
ax=sns.countplot(x="14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ",data=df)
print(df["14 How much time do you explore the e- retail store before making a purchase decision?                                                                   "].value_counts())
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: 14 How much time do you explore the e- retail store before making a purchase decision?                                                                   , dtype: int64

# %%
# most of the people uses more than 15 minutes before purchase it is understood that people are very aware about what to purchase 
# or not .They are thinking before spending

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
ax=sns.countplot(x="15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ",data=df)
print(df["15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               "].value_counts())
# Out:
# Credit/Debit cards                    148
# Cash on delivery (CoD)                 76
# E-wallets (Paytm, Freecharge etc.)     45
# Name: 15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               , dtype: int64

# %%
# most of the people use credit and debit cards for paying
# second preference they use is cash on delivery
# very less people use paytm and freecharge

# %%
ax=sns.countplot(x="16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ",data=df)
print(df["16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   "].value_counts())
# Out:
# Sometimes          171
# Never               48
# Frequently          35
# Very frequently     15
# Name: 16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   , dtype: int64

# %%
# sometimes people abondon the cart and leave the items without making payment
# that means they purchase what is there in their cart

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
ax=sns.countplot(x="17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ",data=df)
print(df["17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       "].value_counts())
# Out:
# Better alternative offer        133
# Promo code not applicable        54
# Change in price                  37
# Lack of trust                    31
# No preferred mode of payment     14
# Name: 17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       , dtype: int64

# %%
# it is observed they abondon because they might have found better alternative for shopping
# or the promotion code is not applicable for that product

# %%
ax=sns.countplot(x="18 The content on the website must be easy to read and understand",data=df)
print(df["18 The content on the website must be easy to read and understand"].value_counts())
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: 18 The content on the website must be easy to read and understand, dtype: int64

# %%
# it is observed that people shop from that particular site because the content on that site must be easy to understand

# %%
ax=sns.countplot(x="19 Information on similar product to the one highlighted  is important for product comparison",data=df)
print(df["19 Information on similar product to the one highlighted  is important for product comparison"].value_counts())
# Out:
# Strongly agree (5)    116
# Agree (4)              92
# Indifferent (3)        43
# Dis-agree (2)          18
# Name: 19 Information on similar product to the one highlighted  is important for product comparison, dtype: int64

# %%
# most of the people strongly agree that the information that is highlighted is very important for product comparision so that 
# the customer can easily know about the product they want to purchase and they must not be misguided

# %%
ax=sns.countplot(x="20 Complete information on listed seller and product being offered is important for purchase decision.",data=df)
print(df["20 Complete information on listed seller and product being offered is important for purchase decision."].value_counts())
# Out:
# Agree (4)                101
# Strongly agree (5)        87
# Indifferent (3)           52
# Dis-agree (2)             18
# Strongly disagree (1)     11
# Name: 20 Complete information on listed seller and product being offered is important for purchase decision., dtype: int64

# %%
# from the above graph it is observed that customer wants whole information about the seller and the product so that
# he/she can take the correct decision

# %%
ax=sns.countplot(x="21 All relevant information on listed products must be stated clearly",data=df)
print(df["21 All relevant information on listed products must be stated clearly"].value_counts())
# Out:
# Agree (4)                132
# Strongly agree (5)       107
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Name: 21 All relevant information on listed products must be stated clearly, dtype: int64

# %%
ax=sns.countplot(x="22 Ease of navigation in website",data=df)
print(df["22 Ease of navigation in website"].value_counts())
# Out:
# Strongly agree (5)       141
# Agree (4)                105
# Strongly disagree (1)     18
# Dis-agree (2)              5
# Name: 22 Ease of navigation in website, dtype: int64

# %%
# according to above observation there should be ease in navigation in website that means the site from which we shop have an interface 
# that should be easily understood by people

# %%
ax=sns.countplot(x="23 Loading and processing speed",data=df)
print(df["23 Loading and processing speed"].value_counts())
# Out:
# Strongly agree (5)       115
# Agree (4)                112
# Dis-agree (2)             18
# Strongly disagree (1)     12
# Indifferent (3)           12
# Name: 23 Loading and processing speed, dtype: int64

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
# loading and processing speed should be good enough so that peoples can browse and navigate easily for the products without delay 
# and also if the speed is good then there would be no wastage of time and also we will not loose our interests

# %%
ax=sns.countplot(x="24 User friendly Interface of the website",data=df)
print(df["24 User friendly Interface of the website"].value_counts())
# Out:
# Strongly agree (5)       189
# Agree (4)                 45
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Indifferent (3)            5
# Name: 24 User friendly Interface of the website, dtype: int64

# %%
# from above graph most of the people agreed that the interface of the website should be userfriendly for the convinience 

# and ease of the people

# %%
ax=sns.countplot(x="25 Convenient Payment methods",data=df)
print(df["25 Convenient Payment methods"].value_counts())
# Out:
# Strongly agree (5)    159
# Agree (4)              80
# Dis-agree (2)          30
# Name: 25 Convenient Payment methods, dtype: int64

# %%
# The methods of payment should be connvinient for everyone say there should be cash on delivery option,credit/debit card option
# etc and all other options should be available for customers

# %%
ax=sns.countplot(x="26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time",data=df)
print(df["26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time"].value_counts())
# Out:
# Strongly agree (5)    141
# Agree (4)              86
# Disagree (2)           30
# indifferent  (3)       12
# Name: 26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time, dtype: int64

# %%
# the online retail store should create trust among customer by delivering the right product(as shown in picture)
#,at right time so that they can trust the online retailer and shop again and again

# %%
ax=sns.countplot(x="27 Empathy (readiness to assist with queries) towards the customers",data=df)
print(df["27 Empathy (readiness to assist with queries) towards the customers"].value_counts())
# Out:
# Strongly agree (5)       194
# Agree (4)                 42
# Strongly disagree (1)     18
# indifferent (3)           15
# Name: 27 Empathy (readiness to assist with queries) towards the customers, dtype: int64

# %%
# there should be ability in online retailer/online store to answer all the queries of their customers.
# and it is necessary for success of online store

# %%
ax=sns.countplot(x="28 Being able to guarantee the privacy of the customer",data=df)
print(df["28 Being able to guarantee the privacy of the customer"].value_counts())
# Out:
# Strongly agree (5)    185
# Agree (4)              58
# indifferent (3)        26
# Name: 28 Being able to guarantee the privacy of the customer, dtype: int64

# %%
# most of the people agree that their information (name,emailid,phone number etc) that they have filled is secured by
# the store and that particular site is liable for its guarantee

# %%
ax=sns.countplot(x="29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)",data=df)
       
print(df["29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)"].value_counts())
# Out:
# Strongly agree (5)       149
# Agree (4)                 94
# indifferent (3)           15
# Strongly disagree (1)     11
# Name: 29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.), dtype: int64

# %%
# most of the people strongly agree that the online shop store should react quickly according to customers needs
# also the site is available on all the channels ie on emails,twitter,social mediaetc

# %%
ax=sns.countplot(x="30 Online shopping gives monetary benefit and discounts",data=df)
       
print(df["30 Online shopping gives monetary benefit and discounts"].value_counts())
# Out:
# Strongly agree (5)       105
# Agree (4)                 85
# indifferent (3)           50
# Strongly disagree (1)     18
# Dis-agree (2)             11
# Name: 30 Online shopping gives monetary benefit and discounts, dtype: int64

# %%
# most of the people thinks that online shopping provides monetary benefits means discount ,offers,sale 
# and because of that people prefer online shopping

# %%
ax=sns.countplot(x="31 Enjoyment is derived from shopping online",data=df)
       
print(df["31 Enjoyment is derived from shopping online"].value_counts())
# Out:
# Strongly agree (5)       86
# indifferent (3)          75
# Agree (4)                59
# Strongly disagree (1)    30
# Dis-agree (2)            19
# Name: 31 Enjoyment is derived from shopping online, dtype: int64

# %%
# according to above observation most people think that it is fun to do online shopping
# but on the contrary some people think in different way might be they think it is necessary to shop from online store

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
ax=sns.countplot(x="32 Shopping online is convenient and flexible",data=df)
       
print(df["32 Shopping online is convenient and flexible"].value_counts())
# Out:
# Strongly agree (5)    146
# Agree (4)              78
# indifferent (3)        33
# Dis-agree (2)          12
# Name: 32 Shopping online is convenient and flexible, dtype: int64

# %%
# most of the people strongly think that online shopping is convinient to shop online as people get what they want sitting at home
# also it can be replaced within 7 days in some online stores
# so most people prefer online shopping

# %%
ax=sns.countplot(x="33 Return and replacement policy of the e-tailer is important for purchase decision",data=df)
       
print(df["33 Return and replacement policy of the e-tailer is important for purchase decision"].value_counts())
# Out:
# Strongly agree (5)    198
# Agree (4)              51
# Dis-agree (2)          20
# Name: 33 Return and replacement policy of the e-tailer is important for purchase decision, dtype: int64

# %%
ax=sns.countplot(x="34 Gaining access to loyalty programs is a benefit of shopping online",data=df)
       
print(df["34 Gaining access to loyalty programs is a benefit of shopping online"].value_counts())
# Out:
# Strongly agree (5)       115
# Agree (4)                 64
# indifferent (3)           64
# Dis-agree (2)             15
# Strongly disagree (1)     11
# Name: 34 Gaining access to loyalty programs is a benefit of shopping online, dtype: int64

# %%
# almost all the people believe that one should see the replacement and return policy before purchasing 
#gaining access to loyalty programs means reward programs or loyalty programs -customers register their personalinformation 
# and are given a unique id and they use that id for making purchase ,earn points and get offers
#most people do that to earn points

# %%
ax=sns.countplot(x="35 Displaying quality Information on the website improves satisfaction of customers",data=df)
       
print(df["35 Displaying quality Information on the website improves satisfaction of customers"].value_counts())
# Out:
# Strongly agree (5)    133
# Agree (4)              80
# indifferent (3)        56
# Name: 35 Displaying quality Information on the website improves satisfaction of customers, dtype: int64

# %%
# people believe that displaying quality information on the website improves the satisfaction of customers
#they without hesitating purchase the products without any fear about the quality

# %%
ax=sns.countplot(x="36 User derive satisfaction while shopping on a good quality website or application",data=df)
       
print(df["36 User derive satisfaction while shopping on a good quality website or application"].value_counts())
# Out:
# Strongly agree (5)    175
# Agree (4)              86
# Dis-agree (2)           8
# Name: 36 User derive satisfaction while shopping on a good quality website or application, dtype: int64

# %%
# it means that the reputation of the website must be good to gain customers satisfaction
# people believe that they buy from a reputed website only .

# %%
ax=sns.countplot(x="37 Net Benefit derived from shopping online can lead to users satisfaction",data=df)
       
print(df["37 Net Benefit derived from shopping online can lead to users satisfaction"].value_counts())
# Out:
# Strongly agree (5)    164
# Agree (4)              54
# indifferent (3)        40
# Dis-agree (2)          11
# Name: 37 Net Benefit derived from shopping online can lead to users satisfaction, dtype: int64

# %%
# most of the people strongly agree from the above point that they get benefit while shopping online
# and they are well satisfied with online shopping

# %%
ax=sns.countplot(x="38 User satisfaction cannot exist without trust",data=df)
       
print(df["38 User satisfaction cannot exist without trust"].value_counts())
# Out:
# Strongly agree (5)       122
# Agree (4)                117
# Strongly disagree (1)     18
# Dis-agree (2)              7
# indifferent (3)            5
# Name: 38 User satisfaction cannot exist without trust, dtype: int64

# %%
# almost all the people who do online shopping that they are well satisfied with the website they trust
# so trust must be created by them to gain customers satisfaction

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
ax=sns.countplot(x="39 Offering a wide variety of listed product in several category",data=df)
       
print(df["39 Offering a wide variety of listed product in several category"].value_counts())
# Out:
# Strongly agree (5)    111
# Agree (4)              94
# indifferent (3)        57
# Dis-agree (2)           7
# Name: 39 Offering a wide variety of listed product in several category, dtype: int64

# %%
 # from the above obsevation it is said that having a wide variety of the products in many categories improves the sales of online store
# so for increasing the sales they must always update their stock

# %%
ax=sns.countplot(x="40 Provision of complete and relevant product information",data=df)
       
print(df["40 Provision of complete and relevant product information"].value_counts())
# Out:
# Strongly agree (5)    135
# Agree (4)              98
# indifferent (3)        31
# Disagree (2)            5
# Name: 40 Provision of complete and relevant product information, dtype: int64

# %%
# according to the peoples if online stores want to gain trust of customers and to increase the sales 
# they should give complete and relevant product information

# %%
ax=sns.countplot(x="41 Monetary savings",data=df)
       
print(df["41 Monetary savings"].value_counts())
# Out:
# Strongly agree (5)    148
# Agree (4)              75
# Disagree (2)           31
# indifferent (3)        15
# Name: 41 Monetary savings, dtype: int64

# %%
# most of the people agree that they save money bcoz they might get discounts and some offers

# %%
ax=sns.countplot(x="42 The Convenience of patronizing the online retailer",data=df)
       
print(df["42 The Convenience of patronizing the online retailer"].value_counts())
# Out:
# Agree (4)             138
# indifferent (3)        77
# Strongly agree (5)     54
# Name: 42 The Convenience of patronizing the online retailer, dtype: int64

# %%
# according to me the online store grows only when a customer is loyal and frequently shop there 
# and most of the people agree to this point

# %%
ax=sns.countplot(x="43 Shopping on the website gives you the sense of adventure",data=df)
       
print(df["43 Shopping on the website gives you the sense of adventure"].value_counts())
# Out:
# Agree (4)                101
# indifferent (3)           59
# Strongly agree (5)        54
# Dis-agree (2)             50
# Strongly disagree (1)      5
# Name: 43 Shopping on the website gives you the sense of adventure, dtype: int64

# %%
# most of the people find the adventure to shop online
#might be because they don't know about the quality of product,trust on the online retailer

# %%
ax=sns.countplot(x="44 Shopping on your preferred e-tailer enhances your social status",data=df)
       
print(df["44 Shopping on your preferred e-tailer enhances your social status"].value_counts())
# Out:
# indifferent (3)          100
# Agree (4)                 59
# Strongly agree (5)        48
# Strongly disagree (1)     33
# Dis-agree (2)             29
# Name: 44 Shopping on your preferred e-tailer enhances your social status, dtype: int64

# %%
# most people think differently that shopping on your preferred person or company improves our social status 
# as noone socially knows what you purchase online

# %%
ax=sns.countplot(x="45 You feel gratification shopping on your favorite e-tailer",data=df)
       
print(df["45 You feel gratification shopping on your favorite e-tailer"].value_counts())
# Out:
# indifferent (3)          101
# Strongly agree (5)        65
# Agree (4)                 63
# Disagree (2)              22
# Strongly disagree (1)     18
# Name: 45 You feel gratification shopping on your favorite e-tailer, dtype: int64

# %%
# some people feels pleasurewhen they shop online from their favourite company
# but most of the people thinks differently about this thought

# %%
ax=sns.countplot(x="46 Shopping on the website helps you fulfill certain roles",data=df)
       
print(df["46 Shopping on the website helps you fulfill certain roles"].value_counts())
# Out:
# Agree (4)                88
# indifferent (3)          88
# Strongly agree (5)       38
# Strongly disagree (1)    33
# Dis-agree (2)            22
# Name: 46 Shopping on the website helps you fulfill certain roles, dtype: int64

# %%
ax=sns.countplot(x="47 Getting value for money spent",data=df)
       
print(df["47 Getting value for money spent"].value_counts())
# Out:
# Agree (4)             149
# Strongly agree (5)     82
# indifferent (3)        38
# Name: 47 Getting value for money spent, dtype: int64

# %%
# almost everyone agrees to the above graph that they get valuable and good quality product according to the money they spent
# if they are paying they get good quality product

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
ax=sns.countplot(x="From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ",data=df)
       
print(df["From the following, tick any (or all) of the online retailers you have shopped from;                                                                           "].value_counts())
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         32
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29
# Amazon.in, Flipkart.com, Snapdeal.com                           27
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in                                                       16
# Amazon.in, Paytm.com                                            12
# Amazon.in, Flipkart.com, Paytm.com                               7
# Name: From the following, tick any (or all) of the online retailers you have shopped from;                                                                           , dtype: int64

# %%
# from the above observation it is observed that most of the people buy online from amazon.in
# after that they choose to buy from Flipkart
# and then from other platforms
# might be they get good quality products at reasonable price from amazon

# %%
ax=sns.countplot(x="Easy to use website or application",data=df)
       
print(df["Easy to use website or application"].value_counts())
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    64
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         44
# Amazon.in                                                       29
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                22
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Flipkart.com, Myntra.com                             19
# Paytm.com                                                       12
# Flipkart.com                                                     8
# Amazon.in, Paytm.com                                             7
# Name: Easy to use website or application, dtype: int64

# %%
# most of the people find amazon and flipkart website easy to use might be because of user friendly interface

# %%
ax=sns.countplot(x="Visual appealing web-page layout",data=df)
       
print(df["Visual appealing web-page layout"].value_counts())
# Out:
# Amazon.in, Flipkart.com                                         87
# Amazon.in                                                       44
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    36
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Myntra.com                                           15
# Myntra.com                                                      15
# Flipkart.com, Myntra.com                                        15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Flipkart.com                                                    12
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                11
# Name: Visual appealing web-page layout, dtype: int64

# %%
# according to above observation most of the peoples finds the appealing webpage of amazon and flipkart
# after that they find good layout of myntra and snapdeal also
#Good appealing layout attracts the peoples to buy from that particular website

# %%
ax=sns.countplot(x="Wild variety of product on offer",data=df)
       
print(df["Wild variety of product on offer"].value_counts())
# Out:
# Amazon.in, Flipkart.com                              130
# Amazon.in                                             43
# Amazon.in, Myntra.com                                 20
# Flipkart.com, Myntra.com                              15
# Myntra.com                                            15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     14
# Amazon.in, Flipkart.com, Paytm.com                    13
# Flipkart.com                                          12
# Paytm.com                                              7
# Name: Wild variety of product on offer, dtype: int64

# %%
# according to the graph amazon and flipkart offers variety of products on offer than any other website

# %%
ax=sns.countplot(x="Complete, relevant description information of products",data=df)
       
print(df["Complete, relevant description information of products"].value_counts())
# Out:
# Amazon.in, Flipkart.com                                         100
# Amazon.in                                                        43
# Amazon.in, Flipkart.com, Paytm.com                               24
# Amazon.in, Paytm.com, Myntra.com                                 20
# Amazon.in, Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                14
# Snapdeal.com                                                     12
# Flipkart.com, Snapdeal.com                                       11
# Flipkart.com                                                      8
# Amazon.in, Flipkart.com, Snapdeal.com                             7
# Name: Complete, relevant description information of products, dtype: int64

# %%
# according to above graph it is observed that complete,relevant and correct information about the  products 
# is given correctly by amazon and flipkart as compared to other websites

# %%
ax=sns.countplot(x="Fast loading website speed of website and application",data=df)
       
print(df["Fast loading website speed of website and application"].value_counts())
# Out:
# Amazon.in                                                       51
# Amazon.in, Paytm.com                                            44
# Amazon.in, Flipkart.com, Myntra.com                             30
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30
# Amazon.in, Flipkart.com                                         30
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com, Paytm.com                              25
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Snapdeal.com                                                    12
# Flipkart.com                                                     8
# Name: Fast loading website speed of website and application, dtype: int64

# %%
# the above graph shows that amazon.in has the fast loading website and application .

# %%
ax=sns.countplot(x="Reliability of the website or application",data=df)
       
print(df["Reliability of the website or application"].value_counts())
# Out:
# Amazon.in                                            61
# Amazon.in, Flipkart.com                              50
# Amazon.in, Flipkart.com, Paytm.com                   36
# Amazon.in, Paytm.com, Myntra.com                     35
# Amazon.in, Flipkart.com, Snapdeal.com                18
# Myntra.com                                           15
# Flipkart.com                                         15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com    14
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com     13
# Paytm.com                                            12
# Name: Reliability of the website or application, dtype: int64

# %%
# most reliable website for e shopping according to above graph is amazon and flipkart
# myntra.com,snapdeal is also reliable to some extent

# %%
ax=sns.countplot(x="Quickness to complete purchase",data=df)
       
print(df["Quickness to complete purchase"].value_counts())
# Out:
# Amazon.com                                                   66
# Amazon.com, Flipkart.com, Paytm.com                          47
# Amazon.com, Flipkart.com                                     37
# Amazon.com, Flipkart.com, Myntra.com                         30
# Paytm.com                                                    25
# Amazon.com, Paytm.com, Myntra.com                            20
# Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal    15
# Flipkart.com                                                 15
# Flipkart.com, Myntra.com, Snapdeal                           14
# Name: Quickness to complete purchase, dtype: int64

# %%
#

# %%
ax=sns.countplot(x="Availability of several payment options",data=df)
       
print(df["Availability of several payment options"].value_counts())
# Out:
# Amazon.in, Flipkart.com                                         65
# Amazon.in, Flipkart.com, Myntra.com                             40
# Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com    39
# Amazon.in                                                       23
# Patym.com, Myntra.com                                           20
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               19
# Amazon.in, Flipkart.com, Snapdeal.com                           18
# Flipkart.com, Myntra.com, Snapdeal.com                          14
# Patym.com                                                       12
# Amazon.in, Patym.com                                            11
# Flipkart.com                                                     8
# Name: Availability of several payment options, dtype: int64

# %%
# all the several payment options are available in almost all the shopping platforms
# specially in Amazon and flipkart such as cash on delivery,credit/debit card etc

# %%
ax=sns.countplot(x="Speedy order delivery ",data=df)
       
print(df["Speedy order delivery "].value_counts())
# Out:
# Amazon.in                                 107
# Amazon.in, Flipkart.com                    82
# Amazon.in, Flipkart.com, Snapdeal.com      36
# Amazon.in, Flipkart.com, Myntra.com        15
# Flipkart.com                               15
# Flipkart.com, Myntra.com, Snapdeal.com     14
# Name: Speedy order delivery , dtype: int64

# %%
# order is delivered quickly through Amazon and then through Flipkart
# and this is a benefit for people as they receive their order on time

# %%
ax=sns.countplot(x="Privacy of customers’ information",data=df)
       
print(df["Privacy of customers’ information"].value_counts())
# Out:
# Amazon.in                                                       71
# Amazon.in, Flipkart.com                                         54
# Amazon.in, Flipkart.com, Myntra.com                             25
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    24
# Paytm.com                                                       18
# Myntra.com                                                      15
# Amazon.in, Paytm.com                                            15
# Flipkart.com                                                    15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Amazon.in, Flipkart.com, Snapdeal.com                            7
# Name: Privacy of customers’ information, dtype: int64

# %%
# it is necessary for the e-commerce shopping sites to keep the information of their customers safe 
# thus privacy of customers is necessary for successful eshopping platforms
# Amazon,Flipkart and some other ecompanies tries to do so

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
ax=sns.countplot(x="Security of customer financial information",data=df)
       
print(df["Security of customer financial information"].value_counts())
# Out:
# Amazon.in                                                       51
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    42
# Flipkart.com                                                    33
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com                                         24
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Snapdeal.com                                         19
# Myntra.com                                                      15
# Paytm.com                                                       15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Security of customer financial information, dtype: int64

# %%
# it is the duty of the e-shopping platform to secure the financial information of their customers
#such as their card number for smooth dealing of their products

# %%
ax=sns.countplot(x="Perceived Trustworthiness",data=df)
       
print(df["Perceived Trustworthiness"].value_counts())
# Out:
# Amazon.in                                                       76
# Amazon.in, Flipkart.com, Snapdeal.com                           36
# Amazon.in, Myntra.com                                           35
# Amazon.in, Flipkart.com                                         31
# Flipkart.com                                                    27
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               25
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    13
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Perceived Trustworthiness, dtype: int64

# %%
# Amazon and to the greatextent Flipkart is successful to be as an honest and trustworthy e-shopping platform
# even some people review snapdeal and myntra also to be trustworthy

# %%
ax=sns.countplot(x="Presence of online assistance through multi-channel",data=df)
       
print(df["Presence of online assistance through multi-channel"].value_counts())
# Out:
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal    61
# Amazon.in                                        60
# Amazon.in, Flipkart.com                          39
# Amazon.in, Snapdeal                              26
# Myntra.com                                       20
# Amazon.in, Flipkart.com, Myntra.com              15
# Amazon.in, Myntra.com                            15
# Amazon.in, Flipkart.com, Paytm.com               13
# Paytm.com                                        12
# Flipkart.com                                      8
# Name: Presence of online assistance through multi-channel, dtype: int64

# %%
#according to above observation it must be easy to find e brand online 
# for this e-company have to build the reputation so that it can possess or employ many communication channels

# %%
ax=sns.countplot(x="Longer time to get logged in (promotion, sales period)",data=df)
       
print(df["Longer time to get logged in (promotion, sales period)"].value_counts())
# Out:
# Amazon.in                                57
# Amazon.in, Flipkart.com                  38
# Paytm.com                                38
# Myntra.com                               35
# Amazon.in, Flipkart.com, Snapdeal.com    29
# Snapdeal.com                             25
# Flipkart.com, Paytm.com                  15
# Flipkart.com, Paytm.com, Snapdeal.com    13
# Amazon.in, Paytm.com                     11
# Flipkart.com                              8
# Name: Longer time to get logged in (promotion, sales period), dtype: int64

# %%
# according to above observation Amazon and Flipkart takes longer time to login
# this might be because of 
# *server issues ,* too much traffic, * too many ads etc

# %%
ax=sns.countplot(x="Longer time in displaying graphics and photos (promotion, sales period)",data=df)
       
print(df["Longer time in displaying graphics and photos (promotion, sales period)"].value_counts())
# Out:
# Amazon.in, Flipkart.com                60
# Amazon.in                              39
# Myntra.com                             35
# Snapdeal.com                           34
# Myntra.com, Snapdeal.com               25
# Flipkart.com, Snapdeal.com             19
# Paytm.com                              15
# Flipkart.com                           15
# Amazon.in, Myntra.com, Snapdeal.com    14
# Amazon.in, Paytm.com                   13
# Name: Longer time in displaying graphics and photos (promotion, sales period), dtype: int64

# %%
# online shoppingsites takes longer time in displaying graphics and images might be because the product list is too much

# %%
ax=sns.countplot(x="Late declaration of price (promotion, sales period)",data=df)
       
print(df["Late declaration of price (promotion, sales period)"].value_counts())
# Out:
# Myntra.com                 75
# Paytm.com                  52
# snapdeal.com               41
# Flipkart.com               38
# Amazon.in                  38
# Amazon.in, Paytm.com       13
# Paytm.com, snapdeal.com     7
# Amazon.in, Flipkart.com     5
# Name: Late declaration of price (promotion, sales period), dtype: int64

# %%
# from above observation we can see that myntra.com face this issue
# may be myntra has this strategy firstly they lower the price of products to attract the customers 
# and when they get exited  and open the product description get high price (price hike)

# %%
ax=sns.countplot(x="Longer page loading time (promotion, sales period)",data=df)
       
print(df["Longer page loading time (promotion, sales period)"].value_counts())
# Out:
# Myntra.com                          61
# Paytm.com                           59
# Flipkart.com                        32
# Snapdeal.com                        23
# Amazon.in, Flipkart.com             18
# Amazon.in                           16
# Paytm.com, Snapdeal.com             15
# Amazon.in, Snapdeal.com             14
# Amazon.in, Paytm.com                13
# Flipkart.com, Snapdeal.com          11
# Amazon.in, Paytm.com, Myntra.com     7
# Name: Longer page loading time (promotion, sales period), dtype: int64

# %%
#  some sites take longer page loading time and it depends on hosting server,web page design as well as number ,type
# and weight of elements on page
# myntra and paytm.com almost take equal page loading time

# %%
ax=sns.countplot(x="Limited mode of payment on most products (promotion, sales period)",data=df)
       
print(df["Limited mode of payment on most products (promotion, sales period)"].value_counts())
# Out:
# Snapdeal.com                87
# Amazon.in                   62
# Flipkart.com                31
# Amazon.in, Flipkart.com     29
# Paytm.com                   25
# Paytm.com, Snapdeal.com     15
# Amazon.in, Paytm.com        13
# Myntra.com, Snapdeal.com     7
# Name: Limited mode of payment on most products (promotion, sales period), dtype: int64

# %%
# some of e-commerce sites have limited modes of payment 
# such as amazon doesn't have cash on delivery option after pandemic
# might be because of social distancing

# %%
ax=sns.countplot(x="Longer delivery period",data=df)
       
print(df["Longer delivery period"].value_counts())
# Out:
# Paytm.com                  72
# Snapdeal.com               64
# Flipkart.com               44
# Amazon.in                  37
# Paytm.com, Snapdeal.com    26
# Myntra.com                 26
# Name: Longer delivery period, dtype: int64

# %%
# some sites take longer period of time to deliver its products
# might be because their have got lots of orders

# %%
ax=sns.countplot(x="Change in website/Application design",data=df)
       
print(df["Change in website/Application design"].value_counts())
# Out:
# Amazon.in                   96
# Paytm.com                   63
# Amazon.in, Flipkart.com     45
# Myntra.com                  30
# Flipkart.com                20
# Snapdeal.com                 8
# Flipkart.com, Myntra.com     7
# Name: Change in website/Application design, dtype: int64

# %%
# everybody who uses amazon and flipkart to shop online observed that amazon and flipkart have changed their application design
# and this attracts the buyers to shop

# %%
ax=sns.countplot(x="Frequent disruption when moving from one page to another",data=df)
       
print(df["Frequent disruption when moving from one page to another"].value_counts())
# Out:
# Amazon.in                     53
# Myntra.com                    52
# Snapdeal.com                  49
# Paytm.com                     39
# Flipkart.com                  26
# Amazon.in, Flipkart.com       25
# Myntra.com, Snapdeal.com      14
# Flipkart.com, Snapdeal.com    11
# Name: Frequent disruption when moving from one page to another, dtype: int64

# %%
ax=sns.countplot(x="Website is as efficient as before",data=df)
       
print(df["Website is as efficient as before"].value_counts())
# Out:
# Amazon.in                             94
# Flipkart.com                          47
# Amazon.in, Flipkart.com               45
# Amazon.in, Flipkart.com, Paytm.com    25
# Amazon.in, Paytm.com                  18
# Paytm.com                             15
# Myntra.com, Snapdeal.com              14
# Snapdeal.com                          11
# Name: Website is as efficient as before, dtype: int64

# %%
# shopping website might gets changed with time 
# but some popular site have not changed ,it is as efficient as before.
# Amazon and Flipkart are some of those

# %%
ax=sns.countplot(x="Which of the Indian online retailer would you recommend to a friend?",data=df)
       
print(df["Which of the Indian online retailer would you recommend to a friend?"].value_counts())
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %%
# people will suggest Amazon and flipkart for their friends

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
# importing encoder 
from sklearn.preprocessing import OrdinalEncoder

# %%
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
# Data visulization is over 
# from the dataset it is observed that there are lots of string values ,so we will convert it into numerical one through encoding techniques
# correlation of columns with target one
# delete the columns having no relation with target
# seperate the columns into feature and target
# scale the data
# then build our model
#from the above dataset it is observed that Amazon is the site that we can suggest to our friends

# %%
#===================Thank You========================================
